# %% [markdown]
# <a href="https://colab.research.google.com/github/Syntax-code/Codes/blob/master/Color_to_Black%26White.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-aea62b63-9441-4aed-a67d-8e3a07a5894e" name="files[]" multiple disabled />
#      <output id="result-aea62b63-9441-4aed-a67d-8e3a07a5894e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sharon-pittaway-iMdsjoiftZo-unsplash.jpg to sharon-pittaway-iMdsjoiftZo-unsplash.jpg
# Saving robert-katzki-jbtfM0XBeRc-unsplash.jpg to robert-katzki-jbtfM0XBeRc-unsplash.jpg
# Saving pawel-czerwinski-3k9PGKWt7ik-unsplash.jpg to pawel-czerwinski-3k9PGKWt7ik-unsplash.jpg
# User uploaded file "sharon-pittaway-iMdsjoiftZo-unsplash.jpg" with length 1756325 bytes
# User uploaded file "robert-katzki-jbtfM0XBeRc-unsplash.jpg" with length 907970 bytes
# User uploaded file "pawel-czerwinski-3k9PGKWt7ik-unsplash.jpg" with length 2135845 bytes

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.144])

'''def rgb1gray(rgb):
  grayimg = rgb
  grayimg.setflags(write=1)
  height, width, channels = rgb.shape
  for i in range(height):
    for j in range(width):
        grayimg[i,j] = (rgb[i,j][0] + rgb[i,j][1] +  rgb[i,j][2])/3
  return grayimg'''

img = mpimg.imread('img2.jpg')

gray = rgb2gray(img)

plt.imshow(gray, cmap = plt.get_cmap('gray'))

plt.savefig('gimg2.png')

plt.show()

# %%
plt.imshow(img)
